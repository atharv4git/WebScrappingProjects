# %%
from flask import Flask , render_template , request , jsonify

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipcart_url = "https://www.flipkart.com/search?q="+"oneplus"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=oneplus'

# %%
# we can ping this link from the browser,
# but we will do it from python code

# %%
response_website = urReq(flipcart_url)

# %%
data_flipcart = response_website.read()

# %%
beautified_html = bs(data_flipcart,"html.parser")

# %%
beautified_html
# Out:
# <!DOCTYPE html>
# ...

# %%
beautified_html.find_all("div",{"class":"_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><div><a class="_3WcRHs _2VGJMH" href="/mobiles/~cs-pd2gcimfry/pr?sid=tyy%2C4io&amp;collection-tab-name=Nothing%20Phone%201&amp;param=53688"><div class="_3ywSr_" style="padding-top:25.18%"><div class="_1bEAQy _312yBx" style="padding-top:25.18%"><img alt="A" class="_2OHU_q"/><img alt="A" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/fk-p-flap/100/25/image/ad4a0709c46dcbd1.jpg?q=50"/></div></div></a></div></div>,
# ...

# %%
len(beautified_html.find_all("div",{"class":"_1AtVbE col-12-12"}))
# Out:
# 16

# %%
bigbox = beautified_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox[0]
# Out:
# <div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><div><a class="_3WcRHs _2VGJMH" href="/mobiles/~cs-pd2gcimfry/pr?sid=tyy%2C4io&amp;collection-tab-name=Nothing%20Phone%201&amp;param=53688"><div class="_3ywSr_" style="padding-top:25.18%"><div class="_1bEAQy _312yBx" style="padding-top:25.18%"><img alt="A" class="_2OHU_q"/><img alt="A" class="kJjFO0 _3DIhEh" src="https://rukminim1.flixcart.com/fk-p-flap/100/25/image/ad4a0709c46dcbd1.jpg?q=50"/></div></div></a></div></div>

# %%
bigbox[6].div.div.div.a['href']
# Out:
# '/oneplus-9-5g-arctic-sky-256-gb/p/itm6e4e8a7b40c8d?pid=MOBGDH2EHGM3H5UX&lid=LSTMOBGDH2EHGM3H5UXHEJSCL&marketplace=FLIPKART&q=oneplus&store=search.flipkart.com&srno=s_1_17&otracker=search&fm=organic&iid=46a559df-ca06-401f-b52c-093e2f029602.MOBGDH2EHGM3H5UX.SEARCH&ppt=None&ppn=None&ssid=dh7qcelvb40000001662106040243&qH=43780d550576947f'

# %%
product6 = "https://www.flipkart.com/search?q="+bigbox[6].div.div.div.a['href']

# %%
import requests
product6_req = requests.get(product6)

# %%
product6_req.encoding = 'utf-8'

# %%
bs(product6_req.text,"html.parser")
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/search?q="+bigbox[6].div.div.div.a['href']
# Out:
# 'https://www.flipkart.com/search?q=/oneplus-9-5g-arctic-sky-256-gb/p/itm6e4e8a7b40c8d?pid=MOBGDH2EHGM3H5UX&lid=LSTMOBGDH2EHGM3H5UXHEJSCL&marketplace=FLIPKART&q=oneplus&store=search.flipkart.com&srno=s_1_17&otracker=search&fm=organic&iid=46a559df-ca06-401f-b52c-093e2f029602.MOBGDH2EHGM3H5UX.SEARCH&ppt=None&ppn=None&ssid=dh7qcelvb40000001662106040243&qH=43780d550576947f'

# %%
product6_page = bs(product6_req.text,"html.parser")

# %%
product6_page
# Out:
# <!DOCTYPE html>
# ...

# %%
all_review = product6_page.find_all('div',{"class":"_16PBlm"})

# %%
len(all_review)
# Out:
# 11

# %%
all_review[5]
# Out:
# <div class="_16PBlm _3_IKGE"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Great product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Very good performance overall</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Shubham Kumar</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-e88ab24f-f415-47be-9f58-ea61fba442b6"><span>Certified Buyer</span><span>, Jamshedpur</span></p><div></div><p class="_2sc7ZR">2months ago</p></div><div class="_1e9_Zu"><div class="row"><div class="_27aTsS"><div class="_1LmwT9"><svg class="skCrcq" height="15" width="20" xmlns="http:/
# ...

# %%
rating = all_review[5].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Shubham Kumar</p>]

# %%
all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Shubham Kumar'

# %%
comment_header = all_review[5].div.div.div.p.text

# %%
all_review[2].div.div.find_all('div',{"class":""})[0].div.text
# Out:
# 'Amazing phone 😍😍'

# %%
all_review[5].div.find_all('p',{'class':'_2sc7ZR'})[1].text
# Out:
# '2months ago'

# %%
all_review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Good choice</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Nice phone. But compared to the functions of the previous phone OnePlus 6T this phone's function and structure quality degraded. Previously I was too satisfied with OnePlus 6T.<br/>I upgraded this phone OnePlus 9 but not that much satisfied with the quality.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Ritu Mahapatra</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-8da31ddb-de07-492b-989d-6b71091c6e74"><span>Certified Buyer</
# ...

# %%
product6
# Out:
# 'https://www.flipkart.com/search?q=/oneplus-9-5g-arctic-sky-256-gb/p/itm6e4e8a7b40c8d?pid=MOBGDH2EHGM3H5UX&lid=LSTMOBGDH2EHGM3H5UXHEJSCL&marketplace=FLIPKART&q=oneplus&store=search.flipkart.com&srno=s_1_17&otracker=search&fm=organic&iid=46a559df-ca06-401f-b52c-093e2f029602.MOBGDH2EHGM3H5UX.SEARCH&ppt=None&ppn=None&ssid=dh7qcelvb40000001662106040243&qH=43780d550576947f'

# %%
product6_page.find_all('div',{"class":"CEmiEU"})[0].text
# Out:
# '₹44,999'

# %%
for i in all_review:
    price = product6_page.find_all('div',{"class":"CEmiEU"})[0].text
    rating = i.div.div.div.div.text
    name = i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    comment_header = i.div.div.div.p.text
    long_review = i.div.find_all('p',{"class":"_2sc7ZR"})[0].text
    long = i.div.find_all('div',{"class":""})[0].div.text
    date = i.div.find_all('p',{'class':'_2sc7ZR'})[1].text
    print(name,rating,price,comment_header,long_review,long,date,"\n----------\n")
# Out:
# Ritu Mahapatra 4 ₹44,999 Good choice Ritu Mahapatra Nice phone. But compared to the functions of the previous phone OnePlus 6T this phone's function and structure quality degraded. Previously I was too satisfied with OnePlus 6T.I upgraded this phone OnePlus 9 but not that much satisfied with the quality. 2months ago
# ----------
#
# Flipkart Customer 4 ₹44,999 Pretty good Flipkart Customer Good 1month ago
# ----------
#
# Devendra Prajapati 4 ₹44,999 Value-for-money Devendra Prajapati Amazing phone 😍😍 2months ago
# ----------
#
# Dheerendra Kumar 1 ₹44,999 Worst experience ever! Dheerendra Kumar Very nice mobile & Parformance 2months ago
# ----------
#
# Abhishek  Mahobiya  5 ₹44,999 Brilliant Abhishek  Mahobiya  Very nice phone 17days ago
# ----------
#
# Shubham Kumar 5 ₹44,999 Great product Shubham Kumar Very good performance overall 2months ago
# ----------
#
# Flipkart Customer 5 ₹44,999 Mind-blowing purchase Flipkart Customer Super mobile 24days ago
# ----------
#
# ...

# %%
import mysql.connector as conn
mydb = conn.connect(host="localhost",user = "root" , passwd = "pass")
cursor = mydb.cursor()
cursor.execute("create database if not exists review")
cursor.execute("create table if not exists review.storeview (`name` varchar(30) ,`rating` int,`price` int,comment_header varchar(90),long_review varchar(90),`long` varchar(90),`date` varchar(30))")

# %%
comment_header = []
rating = []
customer_name = []
review =  []
date = []
price = []
for i in range(len(product6_page)):
    # if i != None:
    comment_header.append(product6_req[i].div.div.p.text)
    rating.append(product6_req[i].div.div.div.div.text)
    customer_name.append(product6_req[i].div.div.find_all("p", {"class":"_2sc7ZR _2V5EHH"})[0].text)
    review.append(product6_req[i].div.div.find_all("div", {"class":"t-ZTKy"})[0].text)
    date.append(product6_req[i].div.find_all('p',{"class":"_2sc7ZR"})[1].text)
    price.append(beautified_html.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text)

dict_data = {"customer_name":customer_name,
            "rating":rating,
            "header":comment_header,
             "price":price,
             "date":date,
             "review":review
            }
df = pd.DataFrame(dict_data)
df.to_csv("flipkart_data.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 7>()
#       6 price = []
#       7 for i in range(len(product6_page)):
#       8     # if i != None:
# ----> 9     comment_header.append(product6_req[i].div.div.p.text)
#      10     rating.append(product6_req[i].div.div.div.div.text)
#      11     customer_name.append(product6_req[i].div.div.find_all("p", {"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# TypeError: 'Response' object is not subscriptable
